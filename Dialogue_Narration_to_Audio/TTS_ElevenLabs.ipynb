# %%
#pip install requests

# %% [markdown]
# Romance Genre

# %%
import requests

# === 1. Your ElevenLabs API Key ===
API_KEY = ""  # Replace with your ElevenLabs API key

# === 2. Voice IDs for each character (get from ElevenLabs dashboard) ===
voice_ids = {
    "Mara": "Kucf5LfcW3f8Vti4qB91",
    "Theo": "9P7pmdvw48dwdly7SX9E",
    "Elias": "VOICE_ID_FOR_ELIAS"
}

# === 3. List your lines: (character, text, output filename) ===
dialogues = [
    ("Theo", "I wasn’t sure what to expect.", "theo_s1.wav"),
    ("Mara", "Most people don’t stay long.", "mara_s1.wav"),
    ("Mara", "It’s easier to measure wind and tide... than to ask someone to stay.", "mara_s2.wav"),
    ("Theo", "You don’t let people in easily.", "theo_s3.wav"),
    ("Mara", "It’s not the letting in... it’s the leaving.", "mara_s3.wav"),
    ("Theo", "You’re here.", "theo_s4.wav"),
    ("Mara", "For now.", "mara_s4.wav")
]

# === 4. ElevenLabs API Endpoint ===
def generate_audio(text, voice_id, filename):
    url = f"https://api.elevenlabs.io/v1/text-to-speech/{voice_id}/stream"
    headers = {
        "xi-api-key": API_KEY,
        "Content-Type": "application/json"
    }
    data = {
        "text": text,
        "voice_settings": {
            "stability": 0.4,          # Lower = more expressive, higher = more stable/consistent
            "similarity_boost": 0.7    # Higher = more like original voice
        }
    }
    response = requests.post(url, headers=headers, json=data)
    if response.status_code == 200:
        with open(filename, "wb") as f:
            f.write(response.content)
        print(f"✅ Saved: {filename}")
    else:
        print(f"❌ ERROR for {filename}: {response.status_code} - {response.text}")

# === 5. Run the batch! ===
for character, line, output_file in dialogues:
    voice_id = voice_ids[character]
    generate_audio(line, voice_id, output_file)

# %% [markdown]
# thriller Genre

# %%
import requests

API_KEY = ""  # Replace with your ElevenLabs API key

voice_ids = {
    "Mara": "Kucf5LfcW3f8Vti4qB91",   # Use Mara's 
    "Theo": "9P7pmdvw48dwdly7SX9E",   # Use Theo's ID
    "Elias": "pqHfZKP75CvOlQylNhV4",    # Replace with Elias's actual ID
    "Narrator": "JBFqnCBsd6RMkjVDRZzb"  # Use a deep, calm male voice
}

dialogues = [
    # NARRATOR (calm, chilling, external):
    ("Narrator", "There were three of them at Lantern Point... and none of them trusted each other.", "narrator_s1.wav"),
    ("Narrator", "And then... there were four.", "narrator_s2.wav"),
    ("Narrator", "Something moved beneath them... or inside them.", "narrator_s3.wav"),
    
    # MARA (cold, tense moments)
    ("Mara", "This isn’t... research gear.", "mara_s3.wav"),
    ("Mara", "I think... we’re not alone.", "mara_s4.wav"),
    
    # THEO (if you want a line from him)
    # ("Theo", "I'm here to help with the new systems.", "theo_arrival.wav"),
    
    # ELIA (optional, for atmospheric background lines)
     #("Elias", "Let sleeping ghosts lie.", "elias_warning.wav"),
]
def generate_audio(text, voice_id, filename):
    url = f"https://api.elevenlabs.io/v1/text-to-speech/{voice_id}/stream"
    headers = {
        "xi-api-key": API_KEY,
        "Content-Type": "application/json"
    }
    data = {
        "text": text,
        "voice_settings": {
            "stability": 0.3,          # Lower = more emotional (try lower for thriller)
            "similarity_boost": 0.6
        }
    }
    response = requests.post(url, headers=headers, json=data)
    if response.status_code == 200:
        with open(filename, "wb") as f:
            f.write(response.content)
        print(f"✅ Saved: {filename}")
    else:
        print(f"❌ ERROR for {filename}: {response.status_code} - {response.text}")

for character, line, output_file in dialogues:
    voice_id = voice_ids[character]
    generate_audio(line, voice_id, output_file)

# %% [markdown]
# fantasy Genre

# %%
import requests

API_KEY = ""  # Use your ElevenLabs API key

voice_ids = {
    "Mara": "Kucf5LfcW3f8Vti4qB91",
    "Theo": "9P7pmdvw48dwdly7SX9E",
    "Elias": "pqHfZKP75CvOlQylNhV4",
    "Narrator": "JBFqnCBsd6RMkjVDRZzb"
}
dialogues = [
    # NARRATOR (mystical, reverent)
    #("Narrator", "The sea keeps what it’s owed.", "narrator_opening.wav"),
    
    # ELIA (ancient, half-whispered, distant)
    ("Elias", "You're here.", "elias_s2.wav"),
    ("Elias", "There’s something beneath. Not sleeping. Remembering.", "elias_s4.wav"),
    
    # MARA (awe, reverence, tension)
    ("Mara", "It remembers what was owed.", "mara_s7.wav"),
    
    # THEO (neutral, slightly uncertain)
    #("Theo", "I've never seen anything like this before.", "theo_sighting.wav"),
    

]
def generate_audio(text, voice_id, filename):
    url = f"https://api.elevenlabs.io/v1/text-to-speech/{voice_id}/stream"
    headers = {
        "xi-api-key": API_KEY,
        "Content-Type": "application/json"
    }
    data = {
        "text": text,
        "voice_settings": {
            "stability": 0.3,          # Lower for more expressive/mystical
            "similarity_boost": 0.6
        }
    }
    response = requests.post(url, headers=headers, json=data)
    if response.status_code == 200:
        with open(filename, "wb") as f:
            f.write(response.content)
        print(f"✅ Saved: {filename}")
    else:
        print(f"❌ ERROR for {filename}: {response.status_code} - {response.text}")

for character, line, output_file in dialogues:
    voice_id = voice_ids[character]
    generate_audio(line, voice_id, output_file)
